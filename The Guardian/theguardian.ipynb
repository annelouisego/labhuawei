# %%
import pandas as pd 
import numpy as np
from scipy.stats import norm

# %%
df = pd.read_csv('/media/sf_My_Share/theguardian.csv')
df.head()
# Out:
#                                                   id      type   sectionId  \
# 0  business/live/2019/may/31/markets-trump-shock-...  liveblog    business
# 1  technology/2019/may/31/blackberry-shuts-down-b...   article  technology
# 2  technology/2019/may/31/oneplus-7-pro-review-an...   article  technology
# 3  us-news/2019/may/30/john-bolton-present-eviden...   article     us-news
# 4  business/live/2019/may/30/china-us-naked-econo...  liveblog    business
#
#   sectionName    webPublicationDate  \
# 0    Business  2019-05-31T14:49:51Z
# 1  Technology  2019-05-31T12:40:24Z
# 2  Technology  2019-05-31T06:00:27Z
# 3     US news  2019-05-30T22:24:55Z
# 4    Business  2019-05-30T14:14:28Z
#
#                                             webTitle  \
# 0  Markets shaken as Trump announces shock Mexico...
# 1  BlackBerry Messenger shuts down as owners blam...
# 2  OnePlus 7 Pro review: an absolute beast in eve...
# 3  Evidence Iran was behind Gulf attacks to be pr...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 11 columns):
# id                    63 non-null object
# type                  63 non-null object
# sectionId             63 non-null object
# sectionName           63 non-null object
# webPublicationDate    63 non-null object
# webTitle              63 non-null object
# webUrl                63 non-null object
# apiUrl                63 non-null object
# isHosted              63 non-null bool
# pillarId              63 non-null object
# pillarName            63 non-null object
# dtypes: bool(1), object(10)
# memory usage: 5.1+ KB
