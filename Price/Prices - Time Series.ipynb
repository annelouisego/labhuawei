# %%
import pandas as pd
allprices = pd.read_csv("C:/Users/Tandoi/Desktop/AllPrices.csv" , sep = ";")

# %%
allprices.set_index('date')
# Out:
#             P_30_pro  Mate_20_pro    P_30  P_20_pro    P_20  Mate_20  \
# date
# 14/05/2019    920.93       572.07  586.69    525.58  386.66   447.18
# 15/05/2019    922.46       573.02  584.86    452.82  386.60   490.00
# 16/05/2019    920.00       569.99  580.00    451.56  400.11   474.91
# 17/05/2019    919.42       564.00  580.02    451.27  406.49   474.61
# 18/05/2019    920.09       569.99  579.00    451.27  385.28   479.08
# 19/05/2019    919.75       569.99  574.90    451.10  385.13   463.27
# 20/05/2019    920.37       569.90  575.00    525.02  378.69   474.75
# 21/05/2019    925.43       569.89  574.92    524.68  378.44   474.44
# 22/05/2019    891.44       569.49  556.73    523.26  379.56   445.16
# 23/05/2019    893.54       569.49  558.11    518.97  391.34   446.27
# 24/05/2019    895.29       567.49  559.20    519.98  389.34   447.14
# 25/05/2019    895.29       588.34  559.20    513.26  386.62   447.14
# ...

# %%
allprices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 11 columns):
# date            18 non-null object
# P_30_pro        18 non-null float64
# Mate_20_pro     18 non-null float64
# P_30            18 non-null float64
# P_20_pro        18 non-null float64
# P_20            18 non-null float64
# Mate_20         18 non-null float64
# Mate_20_X       18 non-null float64
# Mate_20_Lite    18 non-null float64
# P_Smart         18 non-null float64
# P_30_Lite       18 non-null float64
# dtypes: float64(10), object(1)
# memory usage: 1.6+ KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

allprices.plot('date')
plt.xticks(rotation=45)

plt.legend(['P_30_pro', 'Mate_20_pro', 'P_30', 'P_20_pro' , 'P20' , 'Mate_20' , 'Mate_20_X' , 'Mate_20_Lite', 'P_Smart', 'P_30_Lite'] , loc=2)

# %%
plt.legend(['P_30_pro', 'Mate_20_pro', 'P_30', 'P_20_pro' , 'P20' , 'Mate_20' , 'Mate_20_X' , 'Mate_20_Lite', 'P_Smart', 'P_30_Lite'] , loc=2)
